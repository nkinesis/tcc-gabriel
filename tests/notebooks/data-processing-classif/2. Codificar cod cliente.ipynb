# %%
import pandas as pd
import numpy as np

# %%
url = r'C:\Users\ullma\Documents\Google_Drive\Desktop\Faculdade\2020-1\PTCC\data\new.csv'
original_items = pd.read_csv(url, sep=',')
items_filtered_cols = original_items[['customer_unique_id', 'order_approved_at_month', 'product_id']]
items_filtered_cols[:3]
# Out:
#                  customer_unique_id  order_approved_at_month  \
# 0  861eff4711a542e4b93843c6dd7febb0                        5
# 1  290c77bc529b7ac935b93aa66c333dc3                        1
# 2  060e732b5b29e8181a18229c7b0b2b5e                        5
#
#                          product_id
# 0  a9516a079e37a9c9c36b9b78b10169e8
# 1  4aa6014eceb682077f9dc4bffebc05b0
# 2  bd07b66896d6f1494f5b86251848ced7

# %%
items_filtered_cols_unq = items_filtered_cols[['customer_unique_id']].values
items_filtered_cols_unq = pd.DataFrame(items_filtered_cols_unq, columns = ['cust_id'])
items_filtered_cols_unq['index'] = np.arange(1, len(items_filtered_cols_unq)+1) 
items_filtered_cols_unq
# Out:
#                                 cust_id  index
# 0      861eff4711a542e4b93843c6dd7febb0      1
# 1      290c77bc529b7ac935b93aa66c333dc3      2
# 2      060e732b5b29e8181a18229c7b0b2b5e      3
# 3      259dac757896d24d7702b9acbbff3f3c      4
# 4      345ecd01c38d18a9036ed96c73b8d066      5
# ...                                 ...    ...
# 98661  1a29b476fee25c95fbafc67c5ac95cf8  98662
# 98662  d52a67c98be1cf6a5c84435bd38d095d  98663
# 98663  e9f50caf99f032f0bf3c55141f019d99  98664
# 98664  73c2643a0a458b49f58cea58833b192e  98665
# 98665  84732c5050c01db9b23e19ba39899398  98666
#
# [98666 rows x 2 columns]

# %%
len(items_filtered_cols)
# Out:
# 98666

# %%
counter = 0
items_arr = items_filtered_cols.values
newArr = []
for item in items_arr:
    rs = items_filtered_cols_unq[(items_filtered_cols_unq.cust_id == item[0])]
    newIdx = rs['index'].values[0]
    newArr.append([item[0], newIdx, item[1], item[2]])
    counter = counter + 1
    if counter % 1000 == 0 :
        print(counter)
# Out:
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# 50000
# 51000
# 52000
# 53000
# 54000
# 55000
# 56000
# 57000
# 58000
# 59000
# 60000
# 61000
# 62000
# 63000
# 64000
# 65000
# 66000
# 67000
# 68000
# 69000
# 70000
# 71000
# 72000
# 73000
# 74000
# 75000
# 76000
# 77000
# 78000
# 79000
# 80000
# 81000
# 82000
# 83000
# 84000
# 85000
# 86000
# 87000
# 88000
# 89000
# 90000
# 91000
# 92000
# 93000
# 94000
# 95000
# 96000
# 97000
# 98000

# %%
newArr
# Out:
# [['861eff4711a542e4b93843c6dd7febb0',
#   1,
#   5,
#   'a9516a079e37a9c9c36b9b78b10169e8'],
#  ['290c77bc529b7ac935b93aa66c333dc3',
#   2,
#   1,
#   '4aa6014eceb682077f9dc4bffebc05b0'],
#  ['060e732b5b29e8181a18229c7b0b2b5e',
#   3,
#   5,
#   'bd07b66896d6f1494f5b86251848ced7'],
#  ['259dac757896d24d7702b9acbbff3f3c',
#   4,
#   3,
#   'a5647c44af977b148e0a3a4751a09e2e'],
#  ['345ecd01c38d18a9036ed96c73b8d066',
#   5,
#   7,
#   '9391a573abe00141c56e38d84d7d5b3b'],
#  ['4c93744516667ad3b8f1fb645a3116a4',
#   6,
#   9,
#   '0be701e03657109a8a4d5168122777fb'],
#  ['addec96d2e059c80c30fe6871d30d177',
#   7,
#   2,
#   'b5466db4cecf95c3c1be0ba32538ce1a'],
#  ['57b2a98a409812fe9618067b6b8ebe4f',
#   8,
#   11,
#   '124f74f703e88efe001a10bfa718b6ff'],
#  ['1175e95fb47ddff9de6b2b06188f7e0d',
#   9,
#   1,
#   '08401f48b67a852d06105725c3013eff'],
#  ['9afe194fb833f79e300e37e580171f22',
#   10,
#   1,
#   '78efe838c04bbc568be034082200ac20'],
#  ['2a7745e1ed516b289ed9b29c7d0539a5',
#   11,
# ...

# %%
pd.DataFrame(newArr).to_csv(r'C:\Users\ullma\Documents\Google_Drive\Desktop\Faculdade\2020-1\PTCC\data\new2.csv')
