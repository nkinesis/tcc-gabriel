# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import OrdinalEncoder

# %% [markdown]
# ## Get best sellers and encode

# %%
r_cbr = pd.read_csv(r"C:\Users\Gabriel Ullmann\Desktop\all_tcc_results\online_retail1\gen-cf\g_cbr.csv", sep=",")
r_cbr[:3]
# Out:
#    client_id  product_id  rating
# 0          0        4059       1
# 1          0        3515       2
# 2          0         944       1

# %%
org = pd.read_csv(r"C:\laragon\www\tcc-gabriel\data\uci-online-retail-source\online_retail.csv", sep=",")
org[:3]
# Out:
#   orderId product_id                                desc  avgQty  \
# 0  536365     85123A  WHITE HANGING HEART T-LIGHT HOLDER       6
# 1  536365      71053                 WHITE METAL LANTERN       6
# 2  536365     84406B      CREAM CUPID HEARTS COAT HANGER       8
#
#           month price  clientId         country
# 0  12/1/10 8:26  2,55   17850.0  United Kingdom
# 1  12/1/10 8:26  3,39   17850.0  United Kingdom
# 2  12/1/10 8:26  2,75   17850.0  United Kingdom

# %%
temp_count = org['product_id'].value_counts()
temp_count[:5]
# Out:
# 85123A    2312
# 22423     2203
# 85099B    2159
# 47566     1727
# 20725     1639
# Name: product_id, dtype: int64

# %%
prod_col = []
amount_col = []
temp_count.values
# Out:
# array([2312, 2203, 2159, ...,    1,    1,    1], dtype=int64)

# %%
prod_count = pd.DataFrame(index=range(0, len(temp_count)))
prod_count['product_id'] = temp_count.index
prod_count['amount'] = temp_count.values

# %%
prod_count[:3]
# Out:
#   product_id  amount
# 0     85123A    2312
# 1      22423    2203
# 2     85099B    2159

# %%
encoder = OrdinalEncoder()
encoded_products = encoder.fit_transform(
    prod_count['product_id'].values.reshape(-1, 1))
prod_count['product_id'] = encoded_products
prod_count['product_id'] = prod_count['product_id'].astype('int32');

# %%
prod_count[:3]
# Out:
#    product_id  amount
# 0        3536    2312
# 1        1348    2203
# 2        3515    2159

# %%
prod_count.to_csv(r'C:\Users\Gabriel Ullmann\Desktop\or1.csv')

# %% [markdown]
# ## Union

# %%
bss = pd.read_csv(r"C:\Users\Gabriel Ullmann\Desktop\all_tcc_results\online_retail1\best-seller\or1.csv", sep=",")
bss[:3]
# Out:
#    id  product_id  amount
# 0   0        3536    2312
# 1   1        1348    2203
# 2   2        3515    2159

# %%
bss_values = bss[['product_id', 'amount']].values
bss_dict = {}
for bs in bss_values:
    bss_dict[bs[0]] = bs[1]
bss_dict
# Out:
# {3536: 2312,
#  1348: 2203,
#  3515: 2159,
#  2733: 1727,
#  180: 1639,
#  3305: 1502,
#  1631: 1477,
#  1147: 1476,
#  454: 1385,
#  182: 1350,
#  1314: 1348,
#  1381: 1280,
#  2096: 1267,
#  4062: 1256,
#  1317: 1251,
#  1391: 1239,
#  1862: 1229,
#  944: 1214,
#  1043: 1210,
#  1336: 1202,
#  183: 1197,
#  1313: 1192,
#  1863: 1182,
#  1577: 1180,
#  2179: 1179,
#  1610: 1138,
#  1315: 1137,
#  2102: 1135,
#  2952: 1129,
#  1895: 1111,
#  1637: 1107,
#  1608: 1085,
#  2099: 1084,
#  1128: 1072,
#  179: 1068,
#  1982: 1067,
#  181: 1061,
#  1636: 1026,
#  366: 1015,
#  2092: 1009,
#  1094: 993,
#  1034: 986,
#  1093: 974,
#  339: 967,
#  1392: 963,
#  3516: 960,
#  3346: 946,
#  837: 944,
#  2956: 943,
#  2182: 937,
#  282: 937,
#  2094: 930,
#  1543: 924,
#  2138: 919,
#  1290: 912,
#  468: 904,
#  2095: 896,
#  966: 896,
#  1069: 889,
#  942: 885,
#  429: 882,
#  1544: 881,
#  172: 878,
#  801: 874,
#  1633: 872,
#  3394: 871,
#  177: 858,
#  1813: 850,
#  3517: 842,
# ...

# %%
npd = pd.DataFrame(new_allval, columns=['client_id', 'product_id', 'rating', 'amount'])
npd
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-dbbc708c2340> in <module>
# ----> 1 npd = pd.DataFrame(new_allval, columns=['client_id', 'product_id', 'rating', 'amount'])
#       2 npd
#
# NameError: name 'new_allval' is not defined

# %%
npd.to_csv(r'C:\Users\Gabriel Ullmann\Desktop\gcbr_ratings_amounts.csv')

# %%
for row in r_cbr.values:
    print(bss_dict[row[1]])
    break
# Out:
# 710
