# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
base_ds = pd.read_csv(r"C:\Users\ullma\Documents\TCC\tcc-gabriel\data\olist-processed\olist_processed.csv", sep=",")
base_ds = base_ds.dropna()
base_ds
# Out:
#         clientId country  product_id
# 0          50398      RJ        8361
# 1          87747      SP       28636
# 2          21004      MG       24819
# 3          65566      SP       14831
# 4          37639      SP       21360
# ...          ...     ...         ...
# 112645      4740      MA        9410
# 112646      5124      PR        6416
# 112647     76686      SP       14373
# 112648     87875      SP       19435
# 112649     76679      SP        6694
#
# [112650 rows x 3 columns]

# %%
rated_ds = pd.read_csv(r"C:\Users\ullma\Desktop\all_tcc_results\olist\categ-cf\c_cbr.csv", sep=",")
filtered_by2 = rated_ds[(rated_ds.rating == 2)]
filtered_by2
# Out:
#        client_id  product_id  rating
# 45            45       24471       2
# 62            62        2701       2
# 70            70        6862       2
# 160          157        6862       2
# 168          165        8346       2
# ...          ...         ...     ...
# 98175      95345        8346       2
# 98193      95363        8346       2
# 98211      95380        8512       2
# 98221      95390       28021       2
# 98238      95407       23401       2
#
# [3768 rows x 3 columns]

# %%
npd = pd.read_csv(r"C:\Users\ullma\Desktop\all_tcc_results\olist\best-seller\olist_g_amounts.csv", sep=",")
#npd = rated_ds[(rated_ds.rating == 2)]
npd
# Out:
#          client_id  product_id  rating  amount
# 0                0        6940       1      31
# 1                1       10124       1       7
# 2                2       12581       1       5
# 3                3        4543       1       3
# 4                4       24781       1       1
# ...            ...         ...     ...     ...
# 1430954      95418       27845       3       1
# 1430955      95419        8320       3       1
# 1430956      95419       31681       3       1
# 1430957      95419        9828       3       1
# 1430958      95419       27845       3       1
#
# [1430959 rows x 4 columns]

# %%
ax = sns.lmplot(x="rating", y="amount", data=npd, fit_reg=False).set(title="")
ax.set(xlabel='Frequência de pedidos', ylabel='Avaliação')
